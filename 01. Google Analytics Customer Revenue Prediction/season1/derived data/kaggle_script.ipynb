# %%
import pandas as pd
import numpy as np
import gc
from pandas.core.common import SettingWithCopyWarning
import warnings
from multiprocessing import Pool as Pool
import functools
import logging


def get_keys_for_field(field=None):
    the_dict = {
        'device': [
            'browser',
            'browserSize',
            'browserVersion',
            'deviceCategory',
            'flashVersion',
            'isMobile',
            'language',
            'mobileDeviceBranding',
            'mobileDeviceInfo',
            'mobileDeviceMarketingName',
            'mobileDeviceModel',
            'mobileInputSelector',
            'operatingSystem',
            'operatingSystemVersion',
            'screenColors',
            'screenResolution'
        ],
        'geoNetwork': [
            'city',
            'cityId',
            'continent',
            'country',
            'latitude',
            'longitude',
            'metro',
            'networkDomain',
            'networkLocation',
            'region',
            'subContinent'
        ],
        'totals': [
            'bounces',
            'hits',
            'newVisits',
            'pageviews',
            'transactionRevenue',
            'visits'
        ],
        'trafficSource': [
            'adContent',
            'adwordsClickInfo',
            'campaign',
            'campaignCode',
            'isTrueDirect',
            'keyword',
            'medium',
            'referralPath',
            'source'
        ],
    }

    return the_dict[field]


def apply_func_on_series(data=None, func=None):
    return data.apply(lambda x: func(x))


def multi_apply_func_on_series(df=None, func=None, n_jobs=4):
    p = Pool(n_jobs)
    f_ = p.map(functools.partial(apply_func_on_series, func=func),
               np.array_split(df, n_jobs))
    f_ = pd.concat(f_, axis=0, ignore_index=True)
    p.close()
    p.join()
    return f_.values


def convert_to_dict(x):
    return eval(x.replace('false', 'False')
                .replace('true', 'True')
                .replace('null', 'np.nan'))


def get_dict_field(x_, key_):
    try:
        return x_[key_]
    except KeyError:
        return np.nan


def develop_json_fields(df=None):
    json_fields = ['device', 'geoNetwork', 'totals', 'trafficSource']
    # Get the keys
    for json_field in json_fields:
        # print('Doing Field {}'.format(json_field))
        # Get json field keys to create columns
        the_keys = get_keys_for_field(json_field)
        # Replace the string by a dict
        # print('Transform string to dict')
        df[json_field] = multi_apply_func_on_series(
            df=df[json_field],
            func=convert_to_dict,
            n_jobs=4
        )
        logger.info('{} converted to dict'.format(json_field))
        #         df[json_field] = df[json_field].apply(lambda x: eval(x
        #                                             .replace('false', 'False')
        #                                             .replace('true', 'True')
        #                                             .replace('null', 'np.nan')))
        for k in the_keys:
            # print('Extracting {}'.format(k))
            df[json_field + '.' + k] = df[json_field].apply(lambda x: get_dict_field(x_=x, key_=k))
        del df[json_field]
        gc.collect()
        logger.info('{} fields extracted'.format(json_field))
    return df


def main(nrows=None):
    # Convert train
    train = pd.read_csv('D:/kaggle_compitition/all/train.csv', dtype='object', nrows=nrows, encoding='utf-8')
    train = develop_json_fields(df=train)
    logger.info('Train done')

    # Convert test
    test = pd.read_csv('D:/kaggle_compitition/all/test.csv', dtype='object', nrows=nrows, encoding='utf-8')
    test = develop_json_fields(df=test)
    logger.info('Test done')

    # Check features validity
    for f in train.columns:
        if f not in ['date', 'fullVisitorId', 'sessionId']:
            try:
                train[f] = train[f].astype(np.float64)
                test[f] = test[f].astype(np.float64)
            except (ValueError, TypeError):
                logger.info('{} is a genuine string field'.format(f))
                pass
            except Exception:
                logger.exception('{} enountered an exception'.format(f))
                raise

    logger.info('{}'.format(train['totals.transactionRevenue'].sum()))
    feature_to_drop = []
    for f in train.columns:
        if f not in ['date', 'fullVisitorId', 'sessionId', 'totals.transactionRevenue']:
            if train[f].dtype == 'object':
                try:
                    trn, _ = pd.factorize(train[f])
                    tst, _ = pd.factorize(test[f])
                    if (np.std(trn) == 0) | (np.std(tst) == 0):
                        feature_to_drop.append(f)
                        logger.info('No variation in {}'.format(f))
                except TypeError:
                    feature_to_drop.append(f)
                    logger.info('TypeError exception for {}'.format(f))
            else:
                if (np.std(train[f].fillna(0).values) == 0) | (np.std(test[f].fillna(0).values) == 0):
                    feature_to_drop.append(f)
                    logger.info('No variation in {}'.format(f))
    test.drop(feature_to_drop, axis=1, inplace=True)
    train.drop(feature_to_drop, axis=1, inplace=True)
    logger.info('{}'.format(train['totals.transactionRevenue'].sum()))

    for f in train.columns:
        if train[f].dtype == 'object':
            train[f] = train[f].apply(lambda x: try_encode(x))
            test[f] = test[f].apply(lambda x: try_encode(x))

    test.to_csv('extracted_fields_test.gz', compression='gzip', index=False)
    train.to_csv('extracted_fields_train.gz', compression='gzip', index=False)


def try_encode(x):
    """Used to remove any encoding issues within the data"""
    try:
        return x.encode('utf-8', 'surrogateescape').decode('utf-8')
    except AttributeError:
        return np.nan
    except UnicodeEncodeError:
        return np.nan


def get_logger():
    logger_ = logging.getLogger('main')
    logger_.setLevel(logging.DEBUG)
    fh = logging.FileHandler('logging.log')
    fh.setLevel(logging.DEBUG)
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    formatter = logging.Formatter('[%(levelname)s]%(asctime)s:%(name)s:%(message)s')
    fh.setFormatter(formatter)
    ch.setFormatter(formatter)
    # add the handlers to the logger
    logger_.addHandler(fh)
    logger_.addHandler(ch)

    return logger_


if __name__ == '__main__':
    logger = get_logger()
    try:
        warnings.simplefilter('error', SettingWithCopyWarning)
        gc.enable()
        logger.info('Process started')
        main(nrows=None)
    except Exception as err:
        logger.exception('Exception occured')
        raise
# Out:
# [INFO]2018-10-15 09:49:26,391:main:Process started

# %% [markdown]
# # 2차전

# %%
import pandas as pd
import numpy as np

# DRAGONS
import xgboost as xgb
import lightgbm as lgb
import catboost as cat

# plots
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# pandas / plt options
pd.options.display.max_columns = 999
plt.rcParams['figure.figsize'] = (14, 7)
font = {'family' : 'verdana',
        'weight' : 'bold',
        'size'   : 14}
plt.rc('font', **font)

# remove warnings
import warnings
warnings.simplefilter("ignore")

# garbage collector
import gc
gc.enable()

# %%
train = pd.read_csv('D:/kaggle_compitition/all/extracted_fields_train.gz', dtype={'date': str, 'fullVisitorId': str, 'sessionId':str, 'visitId': np.int64})
test = pd.read_csv('D:/kaggle_compitition/all/extracted_fields_test.gz', dtype={'date': str, 'fullVisitorId': str, 'sessionId':str, 'visitId': np.int64})
train.shape, test.shape
# Out:
# ((903653, 30), (804684, 30))

# %%
# Getting data from leak
train_store_1 = pd.read_csv('D:/kaggle_compitition/all/Train_external_data.csv', low_memory=False, skiprows=6, dtype={"Client Id":'str'})
train_store_2 = pd.read_csv('D:/kaggle_compitition/all/Train_external_data_2.csv', low_memory=False, skiprows=6, dtype={"Client Id":'str'})
test_store_1 = pd.read_csv('D:/kaggle_compitition/all/Test_external_data.csv', low_memory=False, skiprows=6, dtype={"Client Id":'str'})
test_store_2 = pd.read_csv('D:/kaggle_compitition/all/Test_external_data_2.csv', low_memory=False, skiprows=6, dtype={"Client Id":'str'})

# %%
# Getting VisitId from Google Analytics...
for df in [train_store_1, train_store_2, test_store_1, test_store_2]:
    df["visitId"] = df["Client Id"].apply(lambda x: x.split('.', 1)[1]).astype(np.int64)

# %%
# Merge with train/test data
train = train.merge(pd.concat([train_store_1, train_store_2], sort=False), how="left", on="visitId")
test = test.merge(pd.concat([test_store_1, test_store_2], sort=False), how="left", on="visitId")

# Drop Client Id
for df in [train, test]:
    df.drop("Client Id", 1, inplace=True)

# %%
# Cleaning Revenue
for df in [train, test]:
    df["Revenue"].fillna('$', inplace=True)
    df["Revenue"] = df["Revenue"].apply(lambda x: x.replace('$', '').replace(',', ''))
    df["Revenue"] = pd.to_numeric(df["Revenue"], errors="coerce")
    df["Revenue"].fillna(0.0, inplace=True)

# %%
for df in [train_store_1, train_store_2, test_store_1, test_store_2]:
    del df
gc.collect()
# Out:
# 378

# %%
train.visitStartTime = pd.to_datetime(train.visitStartTime, unit='s')
test.visitStartTime = pd.to_datetime(test.visitStartTime, unit='s')
train["date"] = train.visitStartTime
test["date"] = test.visitStartTime

# %%
train.set_index("visitStartTime", inplace=True)
test.set_index("visitStartTime", inplace=True)
train.sort_index(inplace=True)
test.sort_index(inplace=True)

# %%
def clearRare(columnname, limit = 1000):
    # you may search for rare categories in train, train&test, or just test
    #vc = pd.concat([train[columnname], test[columnname]], sort=False).value_counts()
    vc = test[columnname].value_counts()
    
    common = vc > limit
    common = set(common.index[common].values)
    print("Set", sum(vc <= limit), columnname, "categories to 'other';", end=" ")
    
    train.loc[train[columnname].map(lambda x: x not in common), columnname] = 'other'
    test.loc[test[columnname].map(lambda x: x not in common), columnname] = 'other'
    print("now there are", train[columnname].nunique(), "categories in train")

# %%
train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# %%
clearRare("device.browser")
clearRare("device.operatingSystem")
clearRare("geoNetwork.country")
clearRare("geoNetwork.city")
clearRare("geoNetwork.metro")
clearRare("geoNetwork.networkDomain")
clearRare("geoNetwork.region")
clearRare("geoNetwork.subContinent")
clearRare("trafficSource.adContent")
clearRare("trafficSource.campaign")
clearRare("trafficSource.keyword")
clearRare("trafficSource.medium")
clearRare("trafficSource.referralPath")
clearRare("trafficSource.source")
# Out:
# Set 98 device.browser categories to 'other'; now there are 11 categories in train
# Set 15 device.operatingSystem categories to 'other'; now there are 8 categories in train
# Set 160 geoNetwork.country categories to 'other'; now there are 60 categories in train
# Set 656 geoNetwork.city categories to 'other'; now there are 77 categories in train
# Set 86 geoNetwork.metro categories to 'other'; now there are 24 categories in train
# Set 25689 geoNetwork.networkDomain categories to 'other'; now there are 62 categories in train
# Set 314 geoNetwork.region categories to 'other'; now there are 62 categories in train
# Set 5 geoNetwork.subContinent categories to 'other'; now there are 19 categories in train
# Set 46 trafficSource.adContent categories to 'other'; now there are 4 categories in train
# Set 23 trafficSource.campaign categories to 'other'; now there are 5 categories in train
# Set 2409 trafficSource.keyword categories to 'other'; now there are 8 categories in train
# Set 1 trafficSource.medium categories to 'other'; now there are 7 categories in train
# Set 2173 trafficSource.referralPath categories to 'other'; now there are 17 categories in train
# Set 303 trafficSource.source categories to 'other'; now there are 22 categories in train

# %%
# Clearing leaked data:
for df in [train, test]:
    df["Avg. Session Duration"][df["Avg. Session Duration"] == 0] = "00:00:00"
    df["Avg. Session Duration"] = df["Avg. Session Duration"].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
    df["Bounce Rate"] = df["Bounce Rate"].astype(str).apply(lambda x: x.replace('%', '')).astype(float)
    df["Goal Conversion Rate"] = df["Goal Conversion Rate"].astype(str).apply(lambda x: x.replace('%', '')).astype(float)

# %% [markdown]
# # Features

# %%
for df in [train, test]:
    # remember these features were equal, but not always? May be it means something...
    df["id_incoherence"] = pd.to_datetime(df.visitId, unit='s') != df.date
    # remember visitId dublicates?
    df["visitId_dublicates"] = df.visitId.map(df.visitId.value_counts())
    # remember session dublicates?
    df["session_dublicates"] = df.sessionId.map(df.sessionId.value_counts())

# %%
for df in [train, test]:
    df['weekday'] = df['date'].dt.dayofweek.astype(object)
    df['time'] = df['date'].dt.second + df['date'].dt.minute*60 + df['date'].dt.hour*3600
    #df['month'] = df['date'].dt.month   # it must not be included in features during learning!
    df['day'] = df['date'].dt.date       # it must not be included in features during learning!

# %%
df = pd.concat([train, test])
df.sort_values(['fullVisitorId', 'date'], ascending=True, inplace=True)
df['prev_session'] = (df['date'] - df[['fullVisitorId', 'date']].groupby('fullVisitorId')['date'].shift(1)).astype(np.int64) // 1e9 // 60 // 60
df['next_session'] = (df['date'] - df[['fullVisitorId', 'date']].groupby('fullVisitorId')['date'].shift(-1)).astype(np.int64) // 1e9 // 60 // 60
df.sort_index(inplace=True)

train = df[:len(train)]
test = df[len(train):]

# %%
for df in [train, test]:
    df['source.country'] = df['trafficSource.source'] + '_' + df['geoNetwork.country']
    df['campaign.medium'] = df['trafficSource.campaign'] + '_' + df['trafficSource.medium']
    df['browser.category'] = df['device.browser'] + '_' + df['device.deviceCategory']
    df['browser.os'] = df['device.browser'] + '_' + df['device.operatingSystem']

# %%
for df in [train, test]:
    df['device_deviceCategory_channelGrouping'] = df['device.deviceCategory'] + "_" + df['channelGrouping']
    df['channelGrouping_browser'] = df['device.browser'] + "_" + df['channelGrouping']
    df['channelGrouping_OS'] = df['device.operatingSystem'] + "_" + df['channelGrouping']
    
    for i in ['geoNetwork.city', 'geoNetwork.continent', 'geoNetwork.country','geoNetwork.metro', 'geoNetwork.networkDomain', 'geoNetwork.region','geoNetwork.subContinent']:
        for j in ['device.browser','device.deviceCategory', 'device.operatingSystem', 'trafficSource.source']:
            df[i + "_" + j] = df[i] + "_" + df[j]
    
    df['content.source'] = df['trafficSource.adContent'].astype(str) + "_" + df['source.country']
    df['medium.source'] = df['trafficSource.medium'] + "_" + df['source.country']

# %%
for feature in ["totals.hits", "totals.pageviews"]:
    info = pd.concat([train, test], sort=False).groupby("fullVisitorId")[feature].mean()
    train["usermean_" + feature] = train.fullVisitorId.map(info)
    test["usermean_" + feature] = test.fullVisitorId.map(info)
    
for feature in ["visitNumber"]:
    info = pd.concat([train, test], sort=False).groupby("fullVisitorId")[feature].max()
    train["usermax_" + feature] = train.fullVisitorId.map(info)
    test["usermax_" + feature] = test.fullVisitorId.map(info)

# %%
excluded = ['date', 'fullVisitorId', 'sessionId', 'totals.transactionRevenue', 'visitId', 'visitStartTime', 
            'month', 'day', 'help']

cat_cols = [f for f in train.columns if (train[f].dtype == 'object' and f not in excluded)]
real_cols = [f for f in train.columns if (not f in cat_cols and f not in excluded)]

# %%
train[cat_cols].nunique()
# Out:
# channelGrouping                                       8
# device.browser                                       11
# device.deviceCategory                                 3
# device.operatingSystem                                8
# geoNetwork.city                                      77
# geoNetwork.continent                                  6
# geoNetwork.country                                   60
# geoNetwork.metro                                     24
# geoNetwork.networkDomain                             62
# geoNetwork.region                                    62
# geoNetwork.subContinent                              19
# trafficSource.adContent                               4
# trafficSource.campaign                                5
# trafficSource.keyword                                 8
# trafficSource.medium                                  7
# trafficSource.referralPath                           17
# trafficSource.source                                 22
# weekday                                               7
# source.country                                      952
# campaign.medium                                      12
# browser.category                                     32
# browser.os                                           49
# device_deviceCategory_channelGrouping                24
# channelGrouping_browser                              81
# channelGrouping_OS                                   62
# geoNetwork.city_device.browser                      723
# geoNetwork.city_device.deviceCategory               230
# geoNetwork.city_device.operatingSystem              547
# geoNetwork.city_trafficSource.source               1216
# geoNetwork.continent_device.browser                  66
# geoNetwork.continent_device.deviceCategory           18
# geoNetwork.continent_device.operatingSystem          48
# geoNetwork.continent_trafficSource.source           117
# geoNetwork.country_device.browser                   633
# geoNetwork.country_device.deviceCategory            180
# geoNetwork.country_device.operatingSystem           476
# geoNetwork.country_trafficSource.source             952
# geoNetwork.metro_device.browser                     227
# geoNetwork.metro_device.deviceCategory               72
# geoNetwork.metro_device.operatingSystem             170
# geoNetwork.metro_trafficSource.source               430
# geoNetwork.networkDomain_device.browser             598
# geoNetwork.networkDomain_device.deviceCategory      185
# geoNetwork.networkDomain_device.operatingSystem     474
# geoNetwork.networkDomain_trafficSource.source       935
# geoNetwork.region_device.browser                    607
# geoNetwork.region_device.deviceCategory             185
# geoNetwork.region_device.operatingSystem            450
# geoNetwork.region_trafficSource.source              965
# geoNetwork.subContinent_device.browser              209
# geoNetwork.subContinent_device.deviceCategory        57
# geoNetwork.subContinent_device.operatingSystem      152
# geoNetwork.subContinent_trafficSource.source        333
# content.source                                     1106
# medium.source                                      1086
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
for col in cat_cols:
    lbl = LabelEncoder()
    lbl.fit(list(train[col].values.astype('str')) + list(test[col].values.astype('str')))
    train[col] = lbl.transform(list(train[col].values.astype('str')))
    test[col] = lbl.transform(list(test[col].values.astype('str')))

# %%
for col in real_cols:
    train[col] = train[col].astype(float)
    test[col] = test[col].astype(float)

# %%
train[real_cols + cat_cols].head()
# Out:
#                      visitNumber  device.isMobile  totals.bounces  \
# visitStartTime
# 2016-08-01 07:00:12          3.0              1.0             1.0
# 2016-08-01 07:04:26          1.0              0.0             1.0
# 2016-08-01 07:04:41          1.0              1.0             0.0
# 2016-08-01 07:06:01          1.0              0.0             0.0
# 2016-08-01 07:06:10          1.0              0.0             1.0
#
#                      totals.hits  totals.newVisits  totals.pageviews  \
# visitStartTime
# 2016-08-01 07:00:12          1.0               0.0               1.0
# 2016-08-01 07:04:26          1.0               1.0               1.0
# 2016-08-01 07:04:41          5.0               1.0               5.0
# 2016-08-01 07:06:01          9.0               1.0               7.0
# 2016-08-01 07:06:10          1.0               1.0               1.0
#
#                      trafficSource.isTrueDirect  Sessions  \
# visitStartTime
# 2016-08-01 07:00:12                         1.0       0.0
# 2016-08-01 07:04:26                         0.0       0.0
# 2016-08-01 07:04:41                         0.0       0.0
# 2016-08-01 07:06:01                         0.0       0.0
# 2016-08-01 07:06:10                         1.0       0.0
#
#                      Avg. Session Duration  Bounce Rate  Revenue  \
# visitStartTime
# 2016-08-01 07:00:12                    0.0          0.0      0.0
# 2016-08-01 07:04:26                    0.0          0.0      0.0
# 2016-08-01 07:04:41                    0.0          0.0      0.0
# 2016-08-01 07:06:01                    0.0          0.0      0.0
# 2016-08-01 07:06:10                    0.0          0.0      0.0
#
#                      Transactions  Goal Conversion Rate  id_incoherence  \
# visitStartTime
# 2016-08-01 07:00:12           0.0                   0.0             0.0
# 2016-08-01 07:04:26           0.0                   0.0             0.0
# 2016-08-01 07:04:41           0.0                   0.0             0.0
# 2016-08-01 07:06:01           0.0                   0.0             0.0
# 2016-08-01 07:06:10           0.0                   0.0             0.0
#
#                      visitId_dublicates  session_dublicates     time  \
# visitStartTime
# 2016-08-01 07:00:12                 1.0                 1.0  25212.0
# 2016-08-01 07:04:26                 1.0                 1.0  25466.0
# 2016-08-01 07:04:41                 1.0                 1.0  25481.0
# 2016-08-01 07:06:01                 1.0                 1.0  25561.0
# 2016-08-01 07:06:10                 1.0                 1.0  25570.0
#
#                      prev_session  next_session  usermean_totals.hits  \
# visitStartTime
# 2016-08-01 07:00:12    -2562048.0    -2562048.0                   1.0
# 2016-08-01 07:04:26    -2562048.0    -2562048.0                   1.0
# 2016-08-01 07:04:41    -2562048.0    -2562048.0                   5.0
# 2016-08-01 07:06:01    -2562048.0    -2562048.0                   9.0
# 2016-08-01 07:06:10    -2562048.0    -2562048.0                   1.0
#
#                      usermean_totals.pageviews  usermax_visitNumber  \
# visitStartTime
# 2016-08-01 07:00:12                        1.0                  3.0
# 2016-08-01 07:04:26                        1.0                  1.0
# 2016-08-01 07:04:41                        5.0                  1.0
# 2016-08-01 07:06:01                        7.0                  1.0
# 2016-08-01 07:06:10                        1.0                  1.0
#
#                      channelGrouping  device.browser  device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                2               7                      1
# 2016-08-01 07:04:26                7               1                      0
# 2016-08-01 07:04:41                4              11                      2
# 2016-08-01 07:06:01                4               1                      0
# 2016-08-01 07:06:10                2               1                      0
#
#                      device.operatingSystem  geoNetwork.city  \
# visitStartTime
# 2016-08-01 07:00:12                       6               75
# 2016-08-01 07:04:26                       5               75
# 2016-08-01 07:04:41                       1               75
# 2016-08-01 07:06:01                       5               75
# 2016-08-01 07:06:10                       5               76
#
#                      geoNetwork.continent  geoNetwork.country  \
# visitStartTime
# 2016-08-01 07:00:12                     2                  57
# 2016-08-01 07:04:26                     3                  52
# 2016-08-01 07:04:41                     2                  57
# 2016-08-01 07:06:01                     2                   8
# 2016-08-01 07:06:10                     3                  36
#
#                      geoNetwork.metro  geoNetwork.networkDomain  \
# visitStartTime
# 2016-08-01 07:00:12                22                         0
# 2016-08-01 07:04:26                22                        51
# 2016-08-01 07:04:41                22                         0
# 2016-08-01 07:06:01                22                         8
# 2016-08-01 07:06:10                 0                        29
#
#                      geoNetwork.region  geoNetwork.subContinent  \
# visitStartTime
# 2016-08-01 07:00:12                 61                        8
# 2016-08-01 07:04:26                 61                       11
# 2016-08-01 07:04:41                 61                        8
# 2016-08-01 07:06:01                 61                        8
# 2016-08-01 07:06:10                 62                       11
#
#                      trafficSource.adContent  trafficSource.campaign  \
# visitStartTime
# 2016-08-01 07:00:12                        0                       1
# 2016-08-01 07:04:26                        0                       1
# 2016-08-01 07:04:41                        0                       1
# 2016-08-01 07:06:01                        0                       1
# 2016-08-01 07:06:10                        0                       1
#
#                      trafficSource.keyword  trafficSource.medium  \
# visitStartTime
# 2016-08-01 07:00:12                      4                     0
# 2016-08-01 07:04:26                      4                     6
# 2016-08-01 07:04:41                      3                     4
# 2016-08-01 07:06:01                      3                     4
# 2016-08-01 07:06:10                      4                     0
#
#                      trafficSource.referralPath  trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                          24                     0
# 2016-08-01 07:04:26                          14                    21
# 2016-08-01 07:04:41                          24                     8
# 2016-08-01 07:06:01                          24                     8
# 2016-08-01 07:06:10                          24                     0
#
#                      weekday  source.country  campaign.medium  \
# visitStartTime
# 2016-08-01 07:00:12        0              57                1
# 2016-08-01 07:04:26        0            1084                7
# 2016-08-01 07:04:41        0             518                5
# 2016-08-01 07:06:01        0             469                5
# 2016-08-01 07:06:10        0              36                1
#
#                      browser.category  browser.os  \
# visitStartTime
# 2016-08-01 07:00:12                25          37
# 2016-08-01 07:04:26                 3           6
# 2016-08-01 07:04:41                35          49
# 2016-08-01 07:06:01                 3           6
# 2016-08-01 07:06:10                 3           6
#
#                      device_deviceCategory_channelGrouping  \
# visitStartTime
# 2016-08-01 07:00:12                                     10
# 2016-08-01 07:04:26                                      7
# 2016-08-01 07:04:41                                     20
# 2016-08-01 07:06:01                                      4
# 2016-08-01 07:06:10                                      2
#
#                      channelGrouping_browser  channelGrouping_OS  \
# visitStartTime
# 2016-08-01 07:00:12                       62                  50
# 2016-08-01 07:04:26                       14                  47
# 2016-08-01 07:04:41                       86                  12
# 2016-08-01 07:06:01                       11                  44
# 2016-08-01 07:06:10                        9                  42
#
#                      geoNetwork.city_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                             831
# 2016-08-01 07:04:26                             825
# 2016-08-01 07:04:41                             835
# 2016-08-01 07:06:01                             825
# 2016-08-01 07:06:10                             837
#
#                      geoNetwork.city_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                    226
# 2016-08-01 07:04:26                                    225
# 2016-08-01 07:04:41                                    227
# 2016-08-01 07:06:01                                    225
# 2016-08-01 07:06:10                                    228
#
#                      geoNetwork.city_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                     564
# 2016-08-01 07:04:26                                     563
# 2016-08-01 07:04:41                                     559
# 2016-08-01 07:06:01                                     563
# 2016-08-01 07:06:10                                     571
#
#                      geoNetwork.city_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                  1359
# 2016-08-01 07:04:26                                  1380
# 2016-08-01 07:04:41                                  1367
# 2016-08-01 07:06:01                                  1367
# 2016-08-01 07:06:10                                  1381
#
#                      geoNetwork.continent_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                                   31
# 2016-08-01 07:04:26                                   37
# 2016-08-01 07:04:41                                   35
# 2016-08-01 07:06:01                                   25
# 2016-08-01 07:06:10                                   37
#
#                      geoNetwork.continent_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                           7
# 2016-08-01 07:04:26                                           9
# 2016-08-01 07:04:41                                           8
# 2016-08-01 07:06:01                                           6
# 2016-08-01 07:06:10                                           9
#
#                      geoNetwork.continent_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                           22
# 2016-08-01 07:04:26                                           29
# 2016-08-01 07:04:41                                           17
# 2016-08-01 07:06:01                                           21
# 2016-08-01 07:06:10                                           29
#
#                      geoNetwork.continent_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                         37
# 2016-08-01 07:04:26                                         80
# 2016-08-01 07:04:41                                         45
# 2016-08-01 07:06:01                                         45
# 2016-08-01 07:06:10                                         59
#
#                      geoNetwork.country_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                                676
# 2016-08-01 07:04:26                                610
# 2016-08-01 07:04:41                                680
# 2016-08-01 07:06:01                                 96
# 2016-08-01 07:06:10                                422
#
#                      geoNetwork.country_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                       172
# 2016-08-01 07:04:26                                       156
# 2016-08-01 07:04:41                                       173
# 2016-08-01 07:06:01                                        24
# 2016-08-01 07:06:10                                       108
#
#                      geoNetwork.country_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                        459
# 2016-08-01 07:04:26                                        418
# 2016-08-01 07:04:41                                        454
# 2016-08-01 07:06:01                                         69
# 2016-08-01 07:06:10                                        290
#
#                      geoNetwork.country_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                     1032
# 2016-08-01 07:04:26                                      956
# 2016-08-01 07:04:41                                     1040
# 2016-08-01 07:06:01                                      149
# 2016-08-01 07:06:10                                      651
#
#                      geoNetwork.metro_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                              252
# 2016-08-01 07:04:26                              246
# 2016-08-01 07:04:41                              256
# 2016-08-01 07:06:01                              246
# 2016-08-01 07:06:10                                1
#
#                      geoNetwork.metro_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                      67
# 2016-08-01 07:04:26                                      66
# 2016-08-01 07:04:41                                      68
# 2016-08-01 07:06:01                                      66
# 2016-08-01 07:06:10                                       0
#
#                      geoNetwork.metro_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                      170
# 2016-08-01 07:04:26                                      169
# 2016-08-01 07:04:41                                      165
# 2016-08-01 07:06:01                                      169
# 2016-08-01 07:06:10                                        5
#
#                      geoNetwork.metro_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                    442
# 2016-08-01 07:04:26                                    463
# 2016-08-01 07:04:41                                    450
# 2016-08-01 07:06:01                                    450
# 2016-08-01 07:06:10                                      0
#
#                      geoNetwork.networkDomain_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                                        7
# 2016-08-01 07:04:26                                      559
# 2016-08-01 07:04:41                                       11
# 2016-08-01 07:06:01                                       90
# 2016-08-01 07:06:10                                      319
#
#                      geoNetwork.networkDomain_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                               1
# 2016-08-01 07:04:26                                             153
# 2016-08-01 07:04:41                                               2
# 2016-08-01 07:06:01                                              24
# 2016-08-01 07:06:10                                              87
#
#                      geoNetwork.networkDomain_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                                6
# 2016-08-01 07:04:26                                              405
# 2016-08-01 07:04:41                                                1
# 2016-08-01 07:06:01                                               69
# 2016-08-01 07:06:10                                              233
#
#                      geoNetwork.networkDomain_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                              0
# 2016-08-01 07:04:26                                            930
# 2016-08-01 07:04:41                                              8
# 2016-08-01 07:06:01                                            151
# 2016-08-01 07:06:10                                            527
#
#                      geoNetwork.region_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                               701
# 2016-08-01 07:04:26                               695
# 2016-08-01 07:04:41                               705
# 2016-08-01 07:06:01                               695
# 2016-08-01 07:06:10                               707
#
#                      geoNetwork.region_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                      184
# 2016-08-01 07:04:26                                      183
# 2016-08-01 07:04:41                                      185
# 2016-08-01 07:06:01                                      183
# 2016-08-01 07:06:10                                      186
#
#                      geoNetwork.region_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                       471
# 2016-08-01 07:04:26                                       470
# 2016-08-01 07:04:41                                       466
# 2016-08-01 07:06:01                                       470
# 2016-08-01 07:06:10                                       478
#
#                      geoNetwork.region_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                    1103
# 2016-08-01 07:04:26                                    1124
# 2016-08-01 07:04:41                                    1111
# 2016-08-01 07:06:01                                    1111
# 2016-08-01 07:06:10                                    1125
#
#                      geoNetwork.subContinent_device.browser  \
# visitStartTime
# 2016-08-01 07:00:12                                     103
# 2016-08-01 07:04:26                                     133
# 2016-08-01 07:04:41                                     107
# 2016-08-01 07:06:01                                      97
# 2016-08-01 07:06:10                                     133
#
#                      geoNetwork.subContinent_device.deviceCategory  \
# visitStartTime
# 2016-08-01 07:00:12                                             25
# 2016-08-01 07:04:26                                             33
# 2016-08-01 07:04:41                                             26
# 2016-08-01 07:06:01                                             24
# 2016-08-01 07:06:10                                             33
#
#                      geoNetwork.subContinent_device.operatingSystem  \
# visitStartTime
# 2016-08-01 07:00:12                                              70
# 2016-08-01 07:04:26                                              93
# 2016-08-01 07:04:41                                              65
# 2016-08-01 07:06:01                                              69
# 2016-08-01 07:06:10                                              93
#
#                      geoNetwork.subContinent_trafficSource.source  \
# visitStartTime
# 2016-08-01 07:00:12                                           153
# 2016-08-01 07:04:26                                           239
# 2016-08-01 07:04:41                                           161
# 2016-08-01 07:06:01                                           161
# 2016-08-01 07:06:10                                           218
#
#                      content.source  medium.source
# visitStartTime
# 2016-08-01 07:00:12              57             57
# 2016-08-01 07:04:26            1084           1237
# 2016-08-01 07:04:41             518            393
# 2016-08-01 07:06:01             469            344
# 2016-08-01 07:06:10              36             36

# %%
for to_del in ["date", "sessionId", "visitId", "day"]:
    del train[to_del]
    del test[to_del]

# %% [markdown]
# # Preparing validation

# %%
excluded = ['date', 'fullVisitorId', 'sessionId', 'totals.transactionRevenue', 'visitId', 'visitStartTime', "month", "help"]

cat_cols = [f for f in train.columns if (train[f].dtype == 'int64' and f not in excluded)]
real_cols = [f for f in train.columns if (not f in cat_cols and f not in excluded)]

# %%
from sklearn.metrics import mean_squared_error
def score(data, y):
    validation_res = pd.DataFrame(
    {"fullVisitorId": data["fullVisitorId"].values,
     "transactionRevenue": data["totals.transactionRevenue"].values,
     "predictedRevenue": np.expm1(y)})

    validation_res = validation_res.groupby("fullVisitorId")["transactionRevenue", "predictedRevenue"].sum().reset_index()
    return np.sqrt(mean_squared_error(np.log1p(validation_res["transactionRevenue"].values), 
                                     np.log1p(validation_res["predictedRevenue"].values)))

# %%
from sklearn.model_selection import GroupKFold

class KFoldValidation():
    def __init__(self, data, n_splits=5):
        unique_vis = np.array(sorted(data['fullVisitorId'].astype(str).unique()))
        folds = GroupKFold(n_splits)
        ids = np.arange(data.shape[0])
        
        self.fold_ids = []
        for trn_vis, val_vis in folds.split(X=unique_vis, y=unique_vis, groups=unique_vis):
            self.fold_ids.append([
                    ids[data['fullVisitorId'].astype(str).isin(unique_vis[trn_vis])],
                    ids[data['fullVisitorId'].astype(str).isin(unique_vis[val_vis])]
                ])
            
    def validate(self, train, test, features, model, name="", prepare_stacking=False, 
                 fit_params={"early_stopping_rounds": 50, "verbose": 100, "eval_metric": "rmse"}):
        model.FI = pd.DataFrame(index=features)
        full_score = 0
        
        if prepare_stacking:
            test[name] = 0
            train[name] = np.NaN
        
        for fold_id, (trn, val) in enumerate(self.fold_ids):
            devel = train[features].iloc[trn]
            y_devel = np.log1p(train["totals.transactionRevenue"].iloc[trn])
            valid = train[features].iloc[val]
            y_valid = np.log1p(train["totals.transactionRevenue"].iloc[val])
                       
            print("Fold ", fold_id, ":")
            model.fit(devel, y_devel, eval_set=[(valid, y_valid)], **fit_params)
            
            if len(model.feature_importances_) == len(features):  # some bugs in catboost?
                model.FI['fold' + str(fold_id)] = model.feature_importances_ / model.feature_importances_.sum()

            predictions = model.predict(valid)
            predictions[predictions < 0] = 0
            print("Fold ", fold_id, " error: ", mean_squared_error(y_valid, predictions)**0.5)
            
            fold_score = score(train.iloc[val], predictions)
            full_score += fold_score / len(self.fold_ids)
            print("Fold ", fold_id, " score: ", fold_score)
            
            if prepare_stacking:
                train[name].iloc[val] = predictions
                
                test_predictions = model.predict(test[features])
                test_predictions[test_predictions < 0] = 0
                test[name] += test_predictions / len(self.fold_ids)
                
        print("Final score: ", full_score)
        return full_score

# %%
Kfolder = KFoldValidation(train)

# %%
lgbmodel = lgb.LGBMRegressor(n_estimators=1000, objective="regression", metric="rmse", num_leaves=31, min_child_samples=100,
                      learning_rate=0.03, bagging_fraction=0.7, feature_fraction=0.5, bagging_frequency=5, 
                      bagging_seed=2019, subsample=.9, colsample_bytree=.9, use_best_model=True)
Kfolder.validate(train, test, real_cols + cat_cols, lgbmodel, "lgbpred", prepare_stacking=True)
# Out:
# Fold  0 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.6217
# [200]	valid_0's rmse: 1.59395
# [300]	valid_0's rmse: 1.58416
# [400]	valid_0's rmse: 1.58092
# [500]	valid_0's rmse: 1.57862
# [600]	valid_0's rmse: 1.57718
# [700]	valid_0's rmse: 1.57635
# [800]	valid_0's rmse: 1.57583
# Early stopping, best iteration is:
# [762]	valid_0's rmse: 1.57581
# Fold  0  error:  1.574468039843558
# Fold  0  score:  1.5555508508875122
# Fold  1 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.59479
# [200]	valid_0's rmse: 1.5714
# [300]	valid_0's rmse: 1.56371
# [400]	valid_0's rmse: 1.55975
# [500]	valid_0's rmse: 1.5579
# [600]	valid_0's rmse: 1.55671
# [700]	valid_0's rmse: 1.55582
# [800]	valid_0's rmse: 1.55549
# Early stopping, best iteration is:
# [781]	valid_0's rmse: 1.55525
# Fold  1  error:  1.5540710953591002
# Fold  1  score:  1.5564294397302254
# Fold  2 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.60651
# [200]	valid_0's rmse: 1.5778
# [300]	valid_0's rmse: 1.5659
# [400]	valid_0's rmse: 1.56101
# [500]	valid_0's rmse: 1.55792
# [600]	valid_0's rmse: 1.55609
# [700]	valid_0's rmse: 1.5548
# [800]	valid_0's rmse: 1.55432
# Early stopping, best iteration is:
# [771]	valid_0's rmse: 1.55409
# Fold  2  error:  1.5526249530362244
# Fold  2  score:  1.5447500053136736
# Fold  3 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.592
# [200]	valid_0's rmse: 1.56662
# [300]	valid_0's rmse: 1.55748
# [400]	valid_0's rmse: 1.55362
# [500]	valid_0's rmse: 1.55188
# [600]	valid_0's rmse: 1.5502
# [700]	valid_0's rmse: 1.5498
# [800]	valid_0's rmse: 1.54964
# Early stopping, best iteration is:
# [790]	valid_0's rmse: 1.54939
# Fold  3  error:  1.5482893706437342
# Fold  3  score:  1.5303327857329767
# Fold  4 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.62963
# [200]	valid_0's rmse: 1.60524
# [300]	valid_0's rmse: 1.59505
# [400]	valid_0's rmse: 1.59044
# [500]	valid_0's rmse: 1.58769
# [600]	valid_0's rmse: 1.5868
# [700]	valid_0's rmse: 1.58612
# [800]	valid_0's rmse: 1.5855
# Early stopping, best iteration is:
# [785]	valid_0's rmse: 1.58545
# Fold  4  error:  1.5838956254709746
# Fold  4  score:  1.563667360925202
# Final score:  1.5501460885179181
# 1.5501460885179181

# %%
lgbmodel.FI.mean(axis=1).sort_values()[:30].plot(kind="barh")

# %%
def create_user_df(df):
    agg_data = df[real_cols + cat_cols + ['fullVisitorId']].groupby('fullVisitorId').mean()
    
    pred_list = df[['fullVisitorId', 'lgbpred']].groupby('fullVisitorId').apply(lambda visitor_df: list(visitor_df.lgbpred))\
        .apply(lambda x: {'pred_'+str(i): pred for i, pred in enumerate(x)})
    all_predictions = pd.DataFrame(list(pred_list.values), index=agg_data.index)
    feats = all_predictions.columns

    all_predictions['t_mean'] = all_predictions.mean(axis=1)
    all_predictions['t_median'] = all_predictions.median(axis=1)   # including t_mean as one of the elements? well, ok
    all_predictions['t_sum_log'] = all_predictions.sum(axis=1)
    all_predictions['t_sum_act'] = all_predictions.fillna(0).sum(axis=1)
    all_predictions['t_nb_sess'] = all_predictions.isnull().sum(axis=1)

    full_data = pd.concat([agg_data, all_predictions], axis=1).astype(float)
    full_data['fullVisitorId'] = full_data.index
    del agg_data, all_predictions
    gc.collect()
    return full_data

# %%
user_train = create_user_df(train)
user_test = create_user_df(test)
features = list(user_train.columns)[:-1]  # don't include "fullVisitorId"
user_train["totals.transactionRevenue"] = train[['fullVisitorId', 'totals.transactionRevenue']].groupby('fullVisitorId').sum()
for f in features:
    if f not in user_test.columns:
        user_test[f] = np.nan

# %%
Kfolder = KFoldValidation(user_train)

# %%
lgbmodel = lgb.LGBMRegressor(n_estimators=1000, objective="regression", metric="rmse", num_leaves=31, min_child_samples=100,
                      learning_rate=0.03, bagging_fraction=0.7, feature_fraction=0.5, bagging_frequency=5, 
                      bagging_seed=2019, subsample=.9, colsample_bytree=.9,
                            use_best_model=True)

# %%
Kfolder.validate(user_train, user_test, features, lgbmodel, name="lgbfinal", prepare_stacking=True)
# Out:
# Fold  0 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.50389
# [200]	valid_0's rmse: 1.4974
# Early stopping, best iteration is:
# [209]	valid_0's rmse: 1.49724
# Fold  0  error:  1.496954331853478
# Fold  0  score:  1.496954331853478
# Fold  1 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.50961
# Early stopping, best iteration is:
# [144]	valid_0's rmse: 1.50648
# Fold  1  error:  1.5063903426869982
# Fold  1  score:  1.5063903426869982
# Fold  2 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.50781
# [200]	valid_0's rmse: 1.50259
# Early stopping, best iteration is:
# [176]	valid_0's rmse: 1.50249
# Fold  2  error:  1.5023974143144654
# Fold  2  score:  1.5023974143144654
# Fold  3 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.48405
# [200]	valid_0's rmse: 1.47826
# Early stopping, best iteration is:
# [216]	valid_0's rmse: 1.47783
# Fold  3  error:  1.4776875493088963
# Fold  3  score:  1.4776875493088963
# Fold  4 :
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.51279
# [200]	valid_0's rmse: 1.5084
# Early stopping, best iteration is:
# [174]	valid_0's rmse: 1.50826
# Fold  4  error:  1.5080099419958084
# Fold  4  score:  1.5080099419958084
# Final score:  1.4982879160319291
# 1.4982879160319291

# %%
xgbmodel = xgb.XGBRegressor(max_depth=22, learning_rate=0.02, n_estimators=1000, 
                                         objective='reg:linear', gamma=1.45, seed=2019, silent=False,
                                        subsample=0.67, colsample_bytree=0.054, colsample_bylevel=0.50)

# %%
Kfolder.validate(user_train, user_test, features, xgbmodel, name="xgbfinal", prepare_stacking=True)
# Out:
# Fold  0 :
# [10:19:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 630 extra nodes, 6 pruned nodes, max_depth=19
# [0]	validation_0-rmse:2.10082
# Will train until validation_0-rmse hasn't improved in 50 rounds.
# [10:19:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4158 extra nodes, 122 pruned nodes, max_depth=22
# [10:19:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3762 extra nodes, 4 pruned nodes, max_depth=22
# [10:19:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2372 extra nodes, 182 pruned nodes, max_depth=22
# [10:19:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=15
# [10:19:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=9
# [10:19:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4460 extra nodes, 134 pruned nodes, max_depth=22
# [10:19:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3158 extra nodes, 34 pruned nodes, max_depth=22
# [10:19:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 870 extra nodes, 64 pruned nodes, max_depth=19
# [10:19:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 930 extra nodes, 14 pruned nodes, max_depth=22
# [10:19:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1774 extra nodes, 48 pruned nodes, max_depth=18
# [10:19:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5082 extra nodes, 180 pruned nodes, max_depth=22
# [10:19:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6204 extra nodes, 188 pruned nodes, max_depth=22
# [10:19:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5824 extra nodes, 310 pruned nodes, max_depth=22
# [10:19:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6934 extra nodes, 286 pruned nodes, max_depth=22
# [10:19:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1848 extra nodes, 96 pruned nodes, max_depth=22
# [10:19:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 12 pruned nodes, max_depth=12
# [10:19:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 32 pruned nodes, max_depth=22
# [10:19:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2324 extra nodes, 330 pruned nodes, max_depth=22
# [10:19:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1824 extra nodes, 194 pruned nodes, max_depth=22
# [10:19:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2492 extra nodes, 84 pruned nodes, max_depth=22
# [10:19:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5922 extra nodes, 704 pruned nodes, max_depth=22
# [10:19:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8356 extra nodes, 990 pruned nodes, max_depth=22
# [10:19:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8046 extra nodes, 954 pruned nodes, max_depth=22
# [10:19:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2732 extra nodes, 398 pruned nodes, max_depth=22
# [10:19:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5012 extra nodes, 1056 pruned nodes, max_depth=22
# [10:19:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6440 extra nodes, 512 pruned nodes, max_depth=22
# [10:19:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6714 extra nodes, 554 pruned nodes, max_depth=22
# [10:19:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 48 pruned nodes, max_depth=22
# [10:19:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3722 extra nodes, 924 pruned nodes, max_depth=22
# [10:19:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 582 extra nodes, 68 pruned nodes, max_depth=22
# [10:19:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2002 extra nodes, 174 pruned nodes, max_depth=20
# [10:19:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1524 extra nodes, 128 pruned nodes, max_depth=22
# [10:19:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5168 extra nodes, 888 pruned nodes, max_depth=22
# [10:19:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4192 extra nodes, 934 pruned nodes, max_depth=22
# [10:19:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2022 extra nodes, 222 pruned nodes, max_depth=22
# [10:19:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1502 extra nodes, 150 pruned nodes, max_depth=22
# [10:19:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3626 extra nodes, 598 pruned nodes, max_depth=22
# [10:19:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3294 extra nodes, 688 pruned nodes, max_depth=22
# [10:19:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1170 extra nodes, 254 pruned nodes, max_depth=22
# [10:19:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=6
# [10:19:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4952 extra nodes, 1088 pruned nodes, max_depth=22
# [10:19:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3472 extra nodes, 748 pruned nodes, max_depth=22
# [10:19:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6156 extra nodes, 1376 pruned nodes, max_depth=22
# [10:19:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5452 extra nodes, 2042 pruned nodes, max_depth=22
# [10:19:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 40 pruned nodes, max_depth=18
# [10:19:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5086 extra nodes, 1594 pruned nodes, max_depth=22
# [10:19:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4676 extra nodes, 1166 pruned nodes, max_depth=22
# [10:19:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4238 extra nodes, 732 pruned nodes, max_depth=22
# [10:19:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 16 pruned nodes, max_depth=12
# [10:19:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 512 extra nodes, 82 pruned nodes, max_depth=21
# [10:19:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3382 extra nodes, 648 pruned nodes, max_depth=15
# [10:19:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 36 pruned nodes, max_depth=12
# [10:19:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2900 extra nodes, 494 pruned nodes, max_depth=22
# [10:19:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6402 extra nodes, 1828 pruned nodes, max_depth=22
# [10:20:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1868 extra nodes, 252 pruned nodes, max_depth=22
# [10:20:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1518 extra nodes, 258 pruned nodes, max_depth=20
# [10:20:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3106 extra nodes, 958 pruned nodes, max_depth=22
# [10:20:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4470 extra nodes, 1592 pruned nodes, max_depth=22
# [10:20:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6890 extra nodes, 3870 pruned nodes, max_depth=22
# [10:20:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 58 pruned nodes, max_depth=16
# [10:20:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 946 extra nodes, 174 pruned nodes, max_depth=22
# [10:20:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 114 pruned nodes, max_depth=22
# [10:20:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1860 extra nodes, 902 pruned nodes, max_depth=22
# [10:20:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 9162 extra nodes, 2428 pruned nodes, max_depth=22
# [10:20:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 790 extra nodes, 424 pruned nodes, max_depth=22
# [10:20:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1256 extra nodes, 618 pruned nodes, max_depth=22
# [10:20:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8472 extra nodes, 3200 pruned nodes, max_depth=22
# [10:20:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 46 pruned nodes, max_depth=19
# [10:20:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 9406 extra nodes, 3650 pruned nodes, max_depth=22
# [10:20:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6398 extra nodes, 3990 pruned nodes, max_depth=22
# [10:20:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 82 pruned nodes, max_depth=16
# [10:20:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5600 extra nodes, 2660 pruned nodes, max_depth=22
# [10:20:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1894 extra nodes, 938 pruned nodes, max_depth=22
# [10:20:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5170 extra nodes, 1102 pruned nodes, max_depth=22
# [10:20:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2650 extra nodes, 1206 pruned nodes, max_depth=22
# [10:20:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7652 extra nodes, 4860 pruned nodes, max_depth=22
# [10:20:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5588 extra nodes, 4032 pruned nodes, max_depth=22
# [10:20:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4068 extra nodes, 1976 pruned nodes, max_depth=22
# [10:20:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7998 extra nodes, 4448 pruned nodes, max_depth=22
# [10:20:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 968 extra nodes, 350 pruned nodes, max_depth=22
# [10:20:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 46 pruned nodes, max_depth=21
# [10:20:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 76 pruned nodes, max_depth=16
# [10:20:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 988 extra nodes, 214 pruned nodes, max_depth=22
# [10:20:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1170 extra nodes, 358 pruned nodes, max_depth=22
# [10:20:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 128 pruned nodes, max_depth=18
# [10:20:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8532 extra nodes, 2710 pruned nodes, max_depth=22
# [10:20:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1732 extra nodes, 1192 pruned nodes, max_depth=22
# [10:20:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3196 extra nodes, 1324 pruned nodes, max_depth=22
# [10:20:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7264 extra nodes, 3950 pruned nodes, max_depth=22
# [10:20:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8054 extra nodes, 2762 pruned nodes, max_depth=22
# [10:20:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=7
# [10:20:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 224 pruned nodes, max_depth=21
# [10:20:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 34 pruned nodes, max_depth=10
# [10:20:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1794 extra nodes, 448 pruned nodes, max_depth=22
# [10:20:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10056 extra nodes, 6784 pruned nodes, max_depth=22
# [10:20:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5930 extra nodes, 2990 pruned nodes, max_depth=22
# [10:20:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 124 pruned nodes, max_depth=22
# [10:20:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2694 extra nodes, 780 pruned nodes, max_depth=22
# [10:20:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 912 extra nodes, 132 pruned nodes, max_depth=13
# [10:20:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 6 pruned nodes, max_depth=9
# [100]	validation_0-rmse:1.61717
# [10:20:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5124 extra nodes, 4186 pruned nodes, max_depth=22
# [10:20:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3162 extra nodes, 1252 pruned nodes, max_depth=22
# [10:20:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 108 pruned nodes, max_depth=18
# [10:20:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3424 extra nodes, 2066 pruned nodes, max_depth=22
# [10:20:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2228 extra nodes, 738 pruned nodes, max_depth=22
# [10:20:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 800 extra nodes, 274 pruned nodes, max_depth=22
# [10:20:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 30 pruned nodes, max_depth=20
# [10:20:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 482 extra nodes, 606 pruned nodes, max_depth=22
# [10:20:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3282 extra nodes, 1124 pruned nodes, max_depth=22
# [10:20:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1720 extra nodes, 2006 pruned nodes, max_depth=22
# [10:20:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3086 extra nodes, 1318 pruned nodes, max_depth=20
# [10:20:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2404 extra nodes, 1772 pruned nodes, max_depth=22
# [10:20:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 996 extra nodes, 230 pruned nodes, max_depth=22
# [10:20:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4118 extra nodes, 3270 pruned nodes, max_depth=22
# [10:20:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 86 pruned nodes, max_depth=19
# [10:20:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2488 extra nodes, 1368 pruned nodes, max_depth=22
# [10:20:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 486 extra nodes, 84 pruned nodes, max_depth=22
# [10:20:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5766 extra nodes, 3486 pruned nodes, max_depth=22
# [10:20:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 836 extra nodes, 132 pruned nodes, max_depth=17
# [10:20:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6982 extra nodes, 4060 pruned nodes, max_depth=22
# [10:20:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 706 extra nodes, 216 pruned nodes, max_depth=22
# [10:20:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3254 extra nodes, 1046 pruned nodes, max_depth=22
# [10:20:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 12 pruned nodes, max_depth=13
# [10:20:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1858 extra nodes, 1452 pruned nodes, max_depth=22
# [10:20:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1178 extra nodes, 332 pruned nodes, max_depth=22
# [10:20:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 814 extra nodes, 146 pruned nodes, max_depth=18
# [10:20:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4332 extra nodes, 2196 pruned nodes, max_depth=22
# [10:20:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2460 extra nodes, 3620 pruned nodes, max_depth=22
# [10:20:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4070 extra nodes, 4720 pruned nodes, max_depth=22
# [10:20:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2432 extra nodes, 1480 pruned nodes, max_depth=22
# [10:20:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3732 extra nodes, 2480 pruned nodes, max_depth=22
# [10:20:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 196 pruned nodes, max_depth=22
# [10:20:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 44 pruned nodes, max_depth=14
# [10:20:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2818 extra nodes, 2984 pruned nodes, max_depth=22
# [10:20:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 140 pruned nodes, max_depth=22
# [10:21:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6478 extra nodes, 9362 pruned nodes, max_depth=22
# [10:21:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 20 pruned nodes, max_depth=22
# [10:21:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3612 extra nodes, 1072 pruned nodes, max_depth=22
# [10:21:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5760 extra nodes, 4278 pruned nodes, max_depth=22
# [10:21:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2548 extra nodes, 3410 pruned nodes, max_depth=22
# [10:21:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5214 extra nodes, 2888 pruned nodes, max_depth=22
# [10:21:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 80 pruned nodes, max_depth=22
# [10:21:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 98 pruned nodes, max_depth=21
# [10:21:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2510 extra nodes, 1142 pruned nodes, max_depth=22
# [10:21:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 958 extra nodes, 290 pruned nodes, max_depth=22
# [10:21:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7332 extra nodes, 8826 pruned nodes, max_depth=22
# [10:21:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 42 pruned nodes, max_depth=14
# [10:21:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3066 extra nodes, 1724 pruned nodes, max_depth=22
# [10:21:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1876 extra nodes, 766 pruned nodes, max_depth=22
# [10:21:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1630 extra nodes, 1720 pruned nodes, max_depth=22
# [10:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8736 extra nodes, 9180 pruned nodes, max_depth=22
# [10:21:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1186 extra nodes, 284 pruned nodes, max_depth=22
# [10:21:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5498 extra nodes, 9290 pruned nodes, max_depth=22
# [10:21:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 208 pruned nodes, max_depth=20
# [10:21:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4256 extra nodes, 3650 pruned nodes, max_depth=22
# [10:21:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 72 pruned nodes, max_depth=10
# [10:21:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 70 pruned nodes, max_depth=12
# [10:21:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 218 pruned nodes, max_depth=20
# [10:21:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1808 extra nodes, 2142 pruned nodes, max_depth=22
# [10:21:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6014 extra nodes, 6006 pruned nodes, max_depth=22
# [10:21:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2248 extra nodes, 4818 pruned nodes, max_depth=22
# [10:21:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2718 extra nodes, 5594 pruned nodes, max_depth=22
# [10:21:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2010 extra nodes, 3552 pruned nodes, max_depth=22
# [10:21:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4506 extra nodes, 2468 pruned nodes, max_depth=22
# [10:21:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2198 extra nodes, 1834 pruned nodes, max_depth=22
# [10:21:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 842 extra nodes, 966 pruned nodes, max_depth=22
# [10:21:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1074 extra nodes, 1234 pruned nodes, max_depth=22
# [10:21:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 988 extra nodes, 220 pruned nodes, max_depth=19
# [10:21:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1378 extra nodes, 730 pruned nodes, max_depth=22
# [10:21:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 36 pruned nodes, max_depth=16
# [10:21:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6408 extra nodes, 8976 pruned nodes, max_depth=22
# [10:21:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 538 extra nodes, 194 pruned nodes, max_depth=22
# [10:21:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4888 extra nodes, 9592 pruned nodes, max_depth=22
# [10:21:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 620 extra nodes, 1132 pruned nodes, max_depth=22
# [10:21:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1234 extra nodes, 3222 pruned nodes, max_depth=22
# [10:21:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2768 extra nodes, 2626 pruned nodes, max_depth=22
# [10:21:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5764 extra nodes, 6336 pruned nodes, max_depth=22
# [10:21:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2924 extra nodes, 5754 pruned nodes, max_depth=22
# [10:21:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6972 extra nodes, 16816 pruned nodes, max_depth=22
# [10:21:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1142 extra nodes, 200 pruned nodes, max_depth=19
# [10:21:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1748 extra nodes, 408 pruned nodes, max_depth=22
# [10:21:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3212 extra nodes, 4882 pruned nodes, max_depth=22
# [10:21:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3276 extra nodes, 826 pruned nodes, max_depth=22
# [10:21:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2090 extra nodes, 732 pruned nodes, max_depth=22
# [10:21:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1996 extra nodes, 3580 pruned nodes, max_depth=22
# [10:21:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4010 extra nodes, 1972 pruned nodes, max_depth=22
# [10:21:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4284 extra nodes, 3466 pruned nodes, max_depth=22
# [10:21:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2672 extra nodes, 702 pruned nodes, max_depth=22
# [10:21:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 402 pruned nodes, max_depth=22
# [10:21:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4948 extra nodes, 6518 pruned nodes, max_depth=22
# [10:21:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7182 extra nodes, 9960 pruned nodes, max_depth=22
# [10:21:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 70 pruned nodes, max_depth=22
# [10:21:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2188 extra nodes, 1566 pruned nodes, max_depth=22
# [10:21:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1418 extra nodes, 3652 pruned nodes, max_depth=22
# [10:21:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5958 extra nodes, 14058 pruned nodes, max_depth=22
# [10:21:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 160 pruned nodes, max_depth=22
# [10:21:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 212 pruned nodes, max_depth=22
# [10:21:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 874 extra nodes, 336 pruned nodes, max_depth=20
# [10:21:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 8 pruned nodes, max_depth=8
# [10:21:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2712 extra nodes, 3870 pruned nodes, max_depth=22
# [200]	validation_0-rmse:1.5456
# [10:21:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 46 pruned nodes, max_depth=9
# [10:21:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4004 extra nodes, 3546 pruned nodes, max_depth=22
# [10:21:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1752 extra nodes, 1482 pruned nodes, max_depth=22
# [10:21:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7516 extra nodes, 14492 pruned nodes, max_depth=22
# [10:21:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4800 extra nodes, 8344 pruned nodes, max_depth=22
# [10:21:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4644 extra nodes, 6254 pruned nodes, max_depth=22
# [10:21:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5466 extra nodes, 3792 pruned nodes, max_depth=22
# [10:21:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 360 pruned nodes, max_depth=22
# [10:22:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5148 extra nodes, 2492 pruned nodes, max_depth=22
# [10:22:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7792 extra nodes, 8172 pruned nodes, max_depth=22
# [10:22:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3330 extra nodes, 1260 pruned nodes, max_depth=22
# [10:22:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 30 pruned nodes, max_depth=22
# [10:22:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3188 extra nodes, 2450 pruned nodes, max_depth=22
# [10:22:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 38 pruned nodes, max_depth=18
# [10:22:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1056 extra nodes, 656 pruned nodes, max_depth=22
# [10:22:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4918 extra nodes, 3696 pruned nodes, max_depth=22
# [10:22:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5708 extra nodes, 17104 pruned nodes, max_depth=22
# [10:22:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1324 extra nodes, 2234 pruned nodes, max_depth=22
# [10:22:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1096 extra nodes, 170 pruned nodes, max_depth=22
# [10:22:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5956 extra nodes, 10176 pruned nodes, max_depth=22
# [10:22:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 118 pruned nodes, max_depth=17
# [10:22:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2000 extra nodes, 2476 pruned nodes, max_depth=22
# [10:22:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2406 extra nodes, 1574 pruned nodes, max_depth=22
# [10:22:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2118 extra nodes, 5932 pruned nodes, max_depth=22
# [10:22:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3276 extra nodes, 3856 pruned nodes, max_depth=22
# [10:22:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2548 extra nodes, 1580 pruned nodes, max_depth=22
# [10:22:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5520 extra nodes, 4760 pruned nodes, max_depth=22
# [10:22:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1324 extra nodes, 500 pruned nodes, max_depth=22
# [10:22:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 11118 extra nodes, 27010 pruned nodes, max_depth=22
# [10:22:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 84 pruned nodes, max_depth=15
# [10:22:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1062 extra nodes, 692 pruned nodes, max_depth=22
# [10:22:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 992 extra nodes, 366 pruned nodes, max_depth=20
# [10:22:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8128 extra nodes, 12290 pruned nodes, max_depth=22
# [10:22:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2948 extra nodes, 2744 pruned nodes, max_depth=22
# [10:22:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5176 extra nodes, 6620 pruned nodes, max_depth=22
# [10:22:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 608 extra nodes, 230 pruned nodes, max_depth=20
# [10:22:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5984 extra nodes, 4192 pruned nodes, max_depth=22
# [10:22:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2486 extra nodes, 2388 pruned nodes, max_depth=22
# [10:22:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3558 extra nodes, 3224 pruned nodes, max_depth=22
# [10:22:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3426 extra nodes, 3876 pruned nodes, max_depth=22
# [10:22:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 930 extra nodes, 534 pruned nodes, max_depth=22
# [10:22:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 794 extra nodes, 854 pruned nodes, max_depth=22
# [10:22:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 102 pruned nodes, max_depth=22
# [10:22:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 652 extra nodes, 292 pruned nodes, max_depth=22
# [10:22:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6426 extra nodes, 6394 pruned nodes, max_depth=22
# [10:22:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1712 extra nodes, 1288 pruned nodes, max_depth=22
# [10:22:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2052 extra nodes, 1708 pruned nodes, max_depth=22
# [10:22:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 778 extra nodes, 322 pruned nodes, max_depth=22
# [10:22:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 868 extra nodes, 630 pruned nodes, max_depth=22
# [10:22:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2882 extra nodes, 1944 pruned nodes, max_depth=22
# [10:22:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 976 extra nodes, 502 pruned nodes, max_depth=22
# [10:22:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1044 extra nodes, 650 pruned nodes, max_depth=22
# [10:22:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2824 extra nodes, 1176 pruned nodes, max_depth=22
# [10:22:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 704 extra nodes, 848 pruned nodes, max_depth=20
# [10:22:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 158 pruned nodes, max_depth=13
# [10:22:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3200 extra nodes, 3178 pruned nodes, max_depth=22
# [10:22:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5684 extra nodes, 9922 pruned nodes, max_depth=21
# [10:22:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5700 extra nodes, 6892 pruned nodes, max_depth=22
# [10:22:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2904 extra nodes, 7398 pruned nodes, max_depth=22
# [10:22:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 122 pruned nodes, max_depth=22
# [10:22:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8962 extra nodes, 10296 pruned nodes, max_depth=22
# [10:22:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 112 pruned nodes, max_depth=22
# [10:22:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5984 extra nodes, 8262 pruned nodes, max_depth=22
# [10:22:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2152 extra nodes, 1510 pruned nodes, max_depth=22
# [10:22:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1180 extra nodes, 580 pruned nodes, max_depth=22
# [10:22:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 2840 pruned nodes, max_depth=22
# [10:22:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5130 extra nodes, 7300 pruned nodes, max_depth=22
# [10:22:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 392 pruned nodes, max_depth=22
# [10:22:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 1376 pruned nodes, max_depth=19
# [10:22:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1480 extra nodes, 3140 pruned nodes, max_depth=22
# [10:22:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 854 extra nodes, 386 pruned nodes, max_depth=22
# [10:22:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4318 extra nodes, 6410 pruned nodes, max_depth=22
# [10:22:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5642 extra nodes, 6114 pruned nodes, max_depth=22
# [10:22:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 582 extra nodes, 244 pruned nodes, max_depth=22
# [10:22:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2580 extra nodes, 2768 pruned nodes, max_depth=22
# [10:22:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1388 extra nodes, 3068 pruned nodes, max_depth=22
# [10:22:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10110 extra nodes, 14740 pruned nodes, max_depth=22
# [10:22:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 330 pruned nodes, max_depth=22
# [10:22:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4226 extra nodes, 3824 pruned nodes, max_depth=22
# [10:22:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1880 extra nodes, 1216 pruned nodes, max_depth=22
# [10:22:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5328 extra nodes, 9092 pruned nodes, max_depth=22
# [10:22:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 668 extra nodes, 560 pruned nodes, max_depth=22
# [10:22:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 1072 pruned nodes, max_depth=22
# [10:22:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5268 extra nodes, 6874 pruned nodes, max_depth=22
# [10:22:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 670 extra nodes, 636 pruned nodes, max_depth=22
# [10:23:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7236 extra nodes, 17168 pruned nodes, max_depth=22
# [10:23:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1482 extra nodes, 910 pruned nodes, max_depth=22
# [10:23:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 540 pruned nodes, max_depth=22
# [10:23:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 600 extra nodes, 944 pruned nodes, max_depth=22
# [10:23:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 666 extra nodes, 566 pruned nodes, max_depth=22
# [10:23:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4404 extra nodes, 4102 pruned nodes, max_depth=22
# [10:23:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3204 extra nodes, 5178 pruned nodes, max_depth=22
# [10:23:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 972 pruned nodes, max_depth=22
# [10:23:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 30 pruned nodes, max_depth=19
# [10:23:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1438 extra nodes, 838 pruned nodes, max_depth=22
# [10:23:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 686 extra nodes, 824 pruned nodes, max_depth=22
# [10:23:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1014 extra nodes, 1892 pruned nodes, max_depth=22
# [10:23:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3924 extra nodes, 3812 pruned nodes, max_depth=22
# [10:23:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 64 pruned nodes, max_depth=20
# [10:23:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 90 pruned nodes, max_depth=21
# [300]	validation_0-rmse:1.5271
# [10:23:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6414 extra nodes, 4958 pruned nodes, max_depth=22
# [10:23:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 826 extra nodes, 1210 pruned nodes, max_depth=22
# [10:23:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1212 extra nodes, 3986 pruned nodes, max_depth=22
# [10:23:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1488 extra nodes, 968 pruned nodes, max_depth=22
# [10:23:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 322 pruned nodes, max_depth=22
# ...
# [11:01:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4322 extra nodes, 11986 pruned nodes, max_depth=22
# [11:01:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4972 extra nodes, 5636 pruned nodes, max_depth=22
# [11:01:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 412 pruned nodes, max_depth=22
# [11:01:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1110 extra nodes, 1566 pruned nodes, max_depth=22
# [11:01:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 90 pruned nodes, max_depth=22
# [11:01:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3936 extra nodes, 3128 pruned nodes, max_depth=22
# [11:01:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 1862 pruned nodes, max_depth=22
# [11:01:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1734 extra nodes, 2474 pruned nodes, max_depth=22
# [11:01:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4938 extra nodes, 1020 pruned nodes, max_depth=22
# [11:01:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5566 extra nodes, 2480 pruned nodes, max_depth=22
# [11:01:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6186 extra nodes, 9522 pruned nodes, max_depth=22
# [11:01:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1200 extra nodes, 2578 pruned nodes, max_depth=22
# [11:01:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3034 extra nodes, 582 pruned nodes, max_depth=21
# [11:01:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 334 pruned nodes, max_depth=21
# [11:01:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4098 extra nodes, 4204 pruned nodes, max_depth=22
# [11:01:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5712 extra nodes, 10050 pruned nodes, max_depth=22
# [11:01:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 212 pruned nodes, max_depth=22
# [11:01:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 588 extra nodes, 370 pruned nodes, max_depth=22
# [11:01:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1932 extra nodes, 3154 pruned nodes, max_depth=22
# [11:01:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 840 extra nodes, 248 pruned nodes, max_depth=22
# [11:01:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 1324 pruned nodes, max_depth=22
# [11:01:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10974 extra nodes, 40158 pruned nodes, max_depth=22
# [11:01:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1808 extra nodes, 1068 pruned nodes, max_depth=22
# [11:01:35] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5568 extra nodes, 9278 pruned nodes, max_depth=22
# [11:01:36] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1746 extra nodes, 2692 pruned nodes, max_depth=22
# [11:01:37] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7216 extra nodes, 9962 pruned nodes, max_depth=22
# [11:01:38] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6180 extra nodes, 13674 pruned nodes, max_depth=22
# [11:01:39] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2598 extra nodes, 2116 pruned nodes, max_depth=22
# [11:01:40] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1406 extra nodes, 1010 pruned nodes, max_depth=22
# [11:01:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 334 pruned nodes, max_depth=22
# [11:01:41] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 682 pruned nodes, max_depth=22
# [11:01:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 582 extra nodes, 596 pruned nodes, max_depth=21
# [400]	validation_0-rmse:1.53055
# [11:01:42] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1802 extra nodes, 1136 pruned nodes, max_depth=22
# [11:01:43] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 508 extra nodes, 716 pruned nodes, max_depth=22
# [11:01:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 366 pruned nodes, max_depth=22
# [11:01:44] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 114 pruned nodes, max_depth=22
# [11:01:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 140 pruned nodes, max_depth=12
# [11:01:45] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 82 pruned nodes, max_depth=20
# [11:01:46] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2014 extra nodes, 2606 pruned nodes, max_depth=22
# [11:01:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5600 extra nodes, 6826 pruned nodes, max_depth=22
# [11:01:47] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 948 extra nodes, 836 pruned nodes, max_depth=20
# [11:01:48] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1894 extra nodes, 3114 pruned nodes, max_depth=22
# [11:01:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 364 pruned nodes, max_depth=21
# [11:01:49] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3450 extra nodes, 1188 pruned nodes, max_depth=22
# [11:01:50] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1354 extra nodes, 1434 pruned nodes, max_depth=22
# [11:01:51] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 766 extra nodes, 824 pruned nodes, max_depth=22
# [11:01:52] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 7694 extra nodes, 12194 pruned nodes, max_depth=22
# [11:01:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4758 extra nodes, 3602 pruned nodes, max_depth=22
# [11:01:53] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 110 pruned nodes, max_depth=21
# [11:01:54] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 5600 extra nodes, 4452 pruned nodes, max_depth=22
# [11:01:55] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 340 pruned nodes, max_depth=22
# [11:01:56] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3836 extra nodes, 4890 pruned nodes, max_depth=22
# [11:01:57] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 904 extra nodes, 1356 pruned nodes, max_depth=22
# [11:01:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6922 extra nodes, 16264 pruned nodes, max_depth=22
# [11:01:58] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1336 extra nodes, 1052 pruned nodes, max_depth=22
# [11:01:59] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2648 extra nodes, 6518 pruned nodes, max_depth=22
# [11:02:00] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 88 pruned nodes, max_depth=22
# [11:02:01] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2786 extra nodes, 9024 pruned nodes, max_depth=22
# [11:02:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 696 extra nodes, 750 pruned nodes, max_depth=21
# [11:02:02] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2298 extra nodes, 3684 pruned nodes, max_depth=22
# [11:02:03] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1206 extra nodes, 1380 pruned nodes, max_depth=22
# [11:02:04] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6274 extra nodes, 9014 pruned nodes, max_depth=22
# [11:02:05] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2106 extra nodes, 1216 pruned nodes, max_depth=22
# [11:02:06] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 350 pruned nodes, max_depth=22
# [11:02:07] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2074 extra nodes, 618 pruned nodes, max_depth=22
# [11:02:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4910 extra nodes, 16978 pruned nodes, max_depth=22
# [11:02:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2982 extra nodes, 7810 pruned nodes, max_depth=22
# [11:02:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 266 pruned nodes, max_depth=19
# [11:02:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 256 pruned nodes, max_depth=13
# [11:02:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1360 extra nodes, 2156 pruned nodes, max_depth=22
# [11:02:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1094 extra nodes, 3338 pruned nodes, max_depth=22
# [11:02:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 106 pruned nodes, max_depth=14
# [11:02:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1474 extra nodes, 1414 pruned nodes, max_depth=21
# [11:02:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 944 extra nodes, 642 pruned nodes, max_depth=22
# [11:02:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1160 extra nodes, 756 pruned nodes, max_depth=22
# [11:02:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3056 extra nodes, 1910 pruned nodes, max_depth=22
# [11:02:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4152 extra nodes, 2730 pruned nodes, max_depth=22
# [11:02:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6594 extra nodes, 4988 pruned nodes, max_depth=22
# [11:02:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3000 extra nodes, 1698 pruned nodes, max_depth=22
# [11:02:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2512 extra nodes, 4784 pruned nodes, max_depth=22
# [11:02:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3576 extra nodes, 1778 pruned nodes, max_depth=22
# [11:02:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4052 extra nodes, 4634 pruned nodes, max_depth=22
# [11:02:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2738 extra nodes, 6772 pruned nodes, max_depth=22
# [11:02:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2550 extra nodes, 6370 pruned nodes, max_depth=22
# [11:02:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4184 extra nodes, 7788 pruned nodes, max_depth=22
# [11:02:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1266 extra nodes, 1602 pruned nodes, max_depth=22
# [11:02:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1444 extra nodes, 276 pruned nodes, max_depth=22
# [11:02:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2322 extra nodes, 7020 pruned nodes, max_depth=22
# [11:02:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1838 extra nodes, 4490 pruned nodes, max_depth=22
# [11:02:27] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 142 pruned nodes, max_depth=22
# [11:02:28] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3740 extra nodes, 4894 pruned nodes, max_depth=22
# [11:02:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1886 extra nodes, 3416 pruned nodes, max_depth=22
# [11:02:29] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 974 extra nodes, 486 pruned nodes, max_depth=22
# [11:02:30] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4184 extra nodes, 2686 pruned nodes, max_depth=22
# [11:02:31] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3326 extra nodes, 6722 pruned nodes, max_depth=22
# [11:02:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3254 extra nodes, 1056 pruned nodes, max_depth=22
# [11:02:32] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 88 pruned nodes, max_depth=22
# [11:02:33] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 492 pruned nodes, max_depth=22
# [11:02:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1148 extra nodes, 500 pruned nodes, max_depth=22
# [11:02:34] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1980 extra nodes, 1678 pruned nodes, max_depth=22
# Stopping. Best iteration:
# [418]	validation_0-rmse:1.53004
#
# Fold  4  error:  1.5297752550950618
# Fold  4  score:  1.529775255099432
# Final score:  1.5216889222762044
# 1.5216889222762044

# %% [markdown]
# # catboost

# %%
catmodel = cat.CatBoostRegressor(iterations=500, learning_rate=0.2, depth=5, random_seed=2019)

# %%
Kfolder.validate(user_train, user_test, features, catmodel, name="catfinal", prepare_stacking=True,
                fit_params={"use_best_model": True, "verbose": 100})
# Out:
# Fold  0 :
# 0:	learn: 1.9255219	test: 1.9279519	best: 1.9279519 (0)	total: 389ms	remaining: 3m 13s
# 100:	learn: 1.4657594	test: 1.5019154	best: 1.5011882 (76)	total: 22.1s	remaining: 1m 27s
# 200:	learn: 1.4380087	test: 1.5022203	best: 1.5007061 (135)	total: 47.4s	remaining: 1m 10s
# 300:	learn: 1.4141213	test: 1.5048838	best: 1.5007061 (135)	total: 1m 12s	remaining: 47.8s
# 400:	learn: 1.3921136	test: 1.5083650	best: 1.5007061 (135)	total: 1m 38s	remaining: 24.2s
# 499:	learn: 1.3732326	test: 1.5111122	best: 1.5007061 (135)	total: 2m 3s	remaining: 0us
#
# bestTest = 1.500706148
# bestIteration = 135
#
# Shrink model to first 136 iterations.
# Fold  0  error:  1.5006562796351786
# Fold  0  score:  1.5006562796351786
# Fold  1 :
# 0:	learn: 1.9254002	test: 1.9318394	best: 1.9318394 (0)	total: 213ms	remaining: 1m 46s
# 100:	learn: 1.4617714	test: 1.5111638	best: 1.5101199 (50)	total: 24.2s	remaining: 1m 35s
# 200:	learn: 1.4318206	test: 1.5176367	best: 1.5101199 (50)	total: 49.3s	remaining: 1m 13s
# 300:	learn: 1.4091028	test: 1.5225200	best: 1.5101199 (50)	total: 1m 15s	remaining: 49.9s
# 400:	learn: 1.3880273	test: 1.5263401	best: 1.5101199 (50)	total: 1m 42s	remaining: 25.2s
# 499:	learn: 1.3679158	test: 1.5295852	best: 1.5101199 (50)	total: 2m 8s	remaining: 0us
#
# bestTest = 1.510119853
# bestIteration = 50
#
# Shrink model to first 51 iterations.
# Fold  1  error:  1.5100938915821396
# Fold  1  score:  1.5100938915821396
# Fold  2 :
# 0:	learn: 1.9243947	test: 1.9297715	best: 1.9297715 (0)	total: 203ms	remaining: 1m 41s
# 100:	learn: 1.4640810	test: 1.5062848	best: 1.5055730 (82)	total: 25.9s	remaining: 1m 42s
# 200:	learn: 1.4368674	test: 1.5087084	best: 1.5055730 (82)	total: 51.9s	remaining: 1m 17s
# 300:	learn: 1.4134153	test: 1.5098796	best: 1.5055730 (82)	total: 1m 18s	remaining: 52s
# 400:	learn: 1.3923639	test: 1.5120567	best: 1.5055730 (82)	total: 1m 46s	remaining: 26.3s
# 499:	learn: 1.3730806	test: 1.5135921	best: 1.5055730 (82)	total: 2m 14s	remaining: 0us
#
# bestTest = 1.505573032
# bestIteration = 82
#
# Shrink model to first 83 iterations.
# Fold  2  error:  1.505478687203318
# Fold  2  score:  1.505478687203318
# Fold  3 :
# 0:	learn: 1.9291828	test: 1.9128077	best: 1.9128077 (0)	total: 216ms	remaining: 1m 47s
# 100:	learn: 1.4689660	test: 1.4801779	best: 1.4776818 (61)	total: 25.6s	remaining: 1m 41s
# 200:	learn: 1.4415531	test: 1.4816435	best: 1.4776818 (61)	total: 53s	remaining: 1m 18s
# 300:	learn: 1.4168744	test: 1.4859663	best: 1.4776818 (61)	total: 1m 21s	remaining: 53.6s
# 400:	learn: 1.3946902	test: 1.4893956	best: 1.4776818 (61)	total: 1m 48s	remaining: 26.8s
# 499:	learn: 1.3748980	test: 1.4938558	best: 1.4776818 (61)	total: 2m 16s	remaining: 0us
#
# bestTest = 1.477681796
# bestIteration = 61
#
# Shrink model to first 62 iterations.
# Fold  3  error:  1.4776651362330926
# Fold  3  score:  1.4776651362330926
# Fold  4 :
# 0:	learn: 1.9237064	test: 1.9326170	best: 1.9326170 (0)	total: 211ms	remaining: 1m 45s
# 100:	learn: 1.4612195	test: 1.5105669	best: 1.5081504 (42)	total: 27.7s	remaining: 1m 49s
# 200:	learn: 1.4323670	test: 1.5137083	best: 1.5081504 (42)	total: 57.8s	remaining: 1m 26s
# 300:	learn: 1.4071640	test: 1.5163569	best: 1.5081504 (42)	total: 1m 25s	remaining: 56.4s
# 400:	learn: 1.3843453	test: 1.5214220	best: 1.5081504 (42)	total: 1m 53s	remaining: 28s
# 499:	learn: 1.3664805	test: 1.5241983	best: 1.5081504 (42)	total: 2m 20s	remaining: 0us
#
# bestTest = 1.508150389
# bestIteration = 42
#
# Shrink model to first 43 iterations.
# Fold  4  error:  1.5081161199066682
# Fold  4  score:  1.5081161199066682
# Final score:  1.5004020229120794
# 1.5004020229120794

# %% [markdown]
# # ensembles

# %%
user_train['PredictedLogRevenue'] = 0.4 * user_train["lgbfinal"] + \
                                    0.2 * user_train["xgbfinal"] + \
                                    0.4 * user_train["catfinal"]
score(user_train, user_train.PredictedLogRevenue)
# Out:
# 1.4968960027748244

# %%
user_test['PredictedLogRevenue'] = 0.15 * user_test["lgbfinal"] +  0.7 * user_test["catfinal"] + 0.15 * user_test["xgbfinal"]

# %%
user_test[['PredictedLogRevenue']].to_csv('leaky submission.csv', index=True)
